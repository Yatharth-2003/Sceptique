# %%
# !pip install GoogleNews
# !pip install newspaper3k
# !pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 KB 12.3 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.1/211.1 KB 13.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 KB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.9/93.9 KB 10.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 39.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13552 sha256=6934e33b9d07d83bf7b2b6e5c3ee1d50222a70c1dfc2cc4caee50055eab1b5aa
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from GoogleNews import GoogleNews
from newspaper import Article
from newspaper import Config
import pandas as pd
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.corpus import stopwords, wordnet
from nltk.stem import PorterStemmer
from nltk import WordNetLemmatizer
from nltk.tokenize import word_tokenize

# %%
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
start_date=[]
end_date=[]
print("Enter the starting Date in mm/dd/yyyy format")
start_date=input()
print("Enter the Last Date in mm/dd/yyyy format")
end_date=input()
# Out:
# Enter the starting Date in mm/dd/yyyy format
# 01/14/2023
# Enter the Last Date in mm/dd/yyyy format
# 01/14/2023

# %%
##Here we can take the input of date and name of celebrity:

googlenews=GoogleNews(start=start_date,end=end_date)  ##Date input function can be created using html and css:

celebrity = []
celebrity = input("Enter The Celebrity Name: ")
googlenews.search(celebrity)
result=googlenews.result()
df=pd.DataFrame(result)  ##This only stores the articles on the first page

##This will store 30 articles, we can also change the number:

for i in range(1,3):
    googlenews.getpage(i)
    result=googlenews.result()
    df=pd.DataFrame(result)
# Out:
# Enter The Celebrity Name: Narendra Modi

# %%
## Here the description section is not giving the full aticles text, so we are using newspaper module:

from newspaper import Article
from newspaper import Config

##We have to take the user_agent somehow from every machine for the downloading error:

# user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36'  ##Yogendra's Machine user_agent
# config = Config()
# config.browser_user_agent = user_agent

list = []
for ind in df.index:
    dict1={}
    article = Article(df['link'][ind])
    # , config=config)
    try:
      article.download()
      article.parse()
      article.nlp()
      dict1['Date']=df['date'][ind]  
      dict1['Media']=df['media'][ind]
      dict1['Title']=str(article.title)
      dict1['Article']=str(article.text)
      list.append(dict1)
    except:
      continue
news_df=pd.DataFrame(list)
# Out:
# /usr/local/lib/python3.8/dist-packages/dateutil/parser/_parser.py:1207: UnknownTimezoneWarning: tzname IST identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "

# %%
news_df.replace(r'^\s*$', np.nan, regex=True,inplace=True)
news_df.dropna()
news_df
# Out:
#               Date               Media  \
# 0       0 mins ago    Deccan Chronicle
# 1      2 hours ago   Business Standard
# 2       7 mins ago            The Week
# 3       2 mins ago       India TV News
# 4      2 hours ago     Hindustan Times
# 5       1 hour ago                Mint
# 6      2 hours ago   Medical Dialogues
# 7      2 hours ago       India TV News
# 8       1 hour ago           Udayavani
# 9       1 hour ago            The Wire
# 10      0 mins ago    Deccan Chronicle
# 11      2 mins ago       India TV News
# 12      7 mins ago            The Week
# 13      1 hour ago                Mint
# 14      1 hour ago          Siasat.com
# 15      1 hour ago             OpIndia
# 16  LIVE1 hour ago  The Indian Express
# 17     2 hours ago         India Today
# 18     2 hours ago          BW Disrupt
# 19     2 hours ago       India TV News
# 20      0 mins ago       India TV News
# 21      1 hour ago             OpIndia
# 22      1 hour ago            ThePrint
# ...

# %%
#Lemmitization process

#1 is tokenizing
news_df['tokenized'] = news_df['Article'].apply(word_tokenize)
#2 is tagging
news_df['pos_tags'] = news_df['tokenized'].apply(nltk.tag.pos_tag)
#3 is simplifying the tagging
def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN
news_df['wordnet_pos'] = news_df['pos_tags'].apply(lambda x: [(word, get_wordnet_pos(pos_tag)) for (word, pos_tag) in x])
#4 calling lemmatizer
wnl = WordNetLemmatizer()
news_df['lemmatized'] = news_df['wordnet_pos'].apply(lambda x: [wnl.lemmatize(word, tag) for word, tag in x])
#5 joining the tokenized words to single string
news_df['Article'] = [' '.join(map(str, l)) for l in news_df['lemmatized']]

news_df.drop(['pos_tags','wordnet_pos','lemmatized','tokenized'],axis=1,inplace=True)

news_df.head()
# Out:
#           Date              Media  \
# 0   0 mins ago   Deccan Chronicle
# 1  2 hours ago  Business Standard
# 2   7 mins ago           The Week
# 3   2 mins ago      India TV News
# 4  2 hours ago    Hindustan Times
#
#                                                Title  \
# 0  PM Modi to virtually flag off Vande Bharat tra...
# 1  PM Modi, EAM Jaishankar extend warm wishes on ...
# 2  Voice of the Global South Summit: India aims f...
# 3  Opinion | Ganga river cruise can be a blessing...
# 4  ‘Pained…’: PM Modi after demise of Congress MP...
#
#                                              Article
# 0  Vande Bharat express from Secunderabad to Viza...
# 1  Prime Minister on Saturday extend his greeting...
# 2  In an attempt to balance the west and with an ...
# 3  Follow u on Image Source : INDIA TV Aaj Ki Baa...
# 4  Prime Minister Narendra Modi on Saturday expre...

# %%
import string
import re
def review_cleaning(text):
    '''Make text lowercase, remove text in square brackets,remove links,remove punctuation
    and remove words containing numbers.'''
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub("'",'',text)
    text = re.sub('\w*\d\w*', '', text)
    return text

news_df['Article']=news_df['Article'].apply(lambda x:review_cleaning(x))
news_df.head()
# Out:
#           Date              Media  \
# 0   0 mins ago   Deccan Chronicle
# 1  2 hours ago  Business Standard
# 2   7 mins ago           The Week
# 3   2 mins ago      India TV News
# 4  2 hours ago    Hindustan Times
#
#                                                Title  \
# 0  PM Modi to virtually flag off Vande Bharat tra...
# 1  PM Modi, EAM Jaishankar extend warm wishes on ...
# 2  Voice of the Global South Summit: India aims f...
# 3  Opinion | Ganga river cruise can be a blessing...
# 4  ‘Pained…’: PM Modi after demise of Congress MP...
#
#                                              Article
# 0  vande bharat express from secunderabad to viza...
# 1  prime minister on saturday extend his greeting...
# 2  in an attempt to balance the west and with an ...
# 3  follow u on image source  india tv aaj ki baat...
# 4  prime minister narendra modi on saturday expre...

# %%
#Removing English stopwords 
stop_words = stopwords.words('english')
stop_words

news_df['Article'] = news_df['Article'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))
news_df.head()
# Out:
#           Date              Media  \
# 0   0 mins ago   Deccan Chronicle
# 1  2 hours ago  Business Standard
# 2   7 mins ago           The Week
# 3   2 mins ago      India TV News
# 4  2 hours ago    Hindustan Times
#
#                                                Title  \
# 0  PM Modi to virtually flag off Vande Bharat tra...
# 1  PM Modi, EAM Jaishankar extend warm wishes on ...
# 2  Voice of the Global South Summit: India aims f...
# 3  Opinion | Ganga river cruise can be a blessing...
# 4  ‘Pained…’: PM Modi after demise of Congress MP...
#
#                                              Article
# 0  vande bharat express secunderabad vizag flag v...
# 1  prime minister saturday extend greeting occasi...
# 2  attempt balance west eye north india hop rally...
# 3  follow u image source india tv aaj ki baat raj...
# 4  prime minister narendra modi saturday express ...

# %%
#Removing additional whitespaces 
news_df['Article'] = news_df['Article'].replace(r'\s+', ' ', regex=True)
news_df.head()
# Out:
#           Date              Media  \
# 0   0 mins ago   Deccan Chronicle
# 1  2 hours ago  Business Standard
# 2   7 mins ago           The Week
# 3   2 mins ago      India TV News
# 4  2 hours ago    Hindustan Times
#
#                                                Title  \
# 0  PM Modi to virtually flag off Vande Bharat tra...
# 1  PM Modi, EAM Jaishankar extend warm wishes on ...
# 2  Voice of the Global South Summit: India aims f...
# 3  Opinion | Ganga river cruise can be a blessing...
# 4  ‘Pained…’: PM Modi after demise of Congress MP...
#
#                                              Article
# 0  vande bharat express secunderabad vizag flag v...
# 1  prime minister saturday extend greeting occasi...
# 2  attempt balance west eye north india hop rally...
# 3  follow u image source india tv aaj ki baat raj...
# 4  prime minister narendra modi saturday express ...

# %%
import pickle

loaded_model = pickle.load(open('/content/fake_news_fulltrained_logistic_2', 'rb'))

# %%
X_test=news_df['Article'].values

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# converting the textual data to numerical data
vectorizer = pickle.load(open('/content/tfidf.pickle','rb'))
# vectorizer.fit(X_test)

X_test = vectorizer.transform(X_test)

# %%
news_df['Authenticity']=''
for i in range(0,len(news_df)):
  X_new = X_test[i]
  news_df['Authenticity'][i] = loaded_model.predict(X_new)
  # print(prediction)
  if (news_df['Authenticity'][i]==0):
    news_df['Authenticity'][i] = 'Real'
  else:
    news_df['Authenticity'][i] = 'Fake'

# %%
news_df
# Out:
#               Date               Media  \
# 0       0 mins ago    Deccan Chronicle
# 1      2 hours ago   Business Standard
# 2       7 mins ago            The Week
# 3       2 mins ago       India TV News
# 4      2 hours ago     Hindustan Times
# 5       1 hour ago                Mint
# 6      2 hours ago   Medical Dialogues
# 7      2 hours ago       India TV News
# 8       1 hour ago           Udayavani
# 9       1 hour ago            The Wire
# 10      0 mins ago    Deccan Chronicle
# 11      2 mins ago       India TV News
# 12      7 mins ago            The Week
# 13      1 hour ago                Mint
# 14      1 hour ago          Siasat.com
# 15      1 hour ago             OpIndia
# 16  LIVE1 hour ago  The Indian Express
# 17     2 hours ago         India Today
# 18     2 hours ago          BW Disrupt
# 19     2 hours ago       India TV News
# 20      0 mins ago       India TV News
# 21      1 hour ago             OpIndia
# 22      1 hour ago            ThePrint
# ...

# %%
from plotly import graph_objs as go
import plotly.express as px
import plotly.figure_factory as ff
from collections import Counter

fig = px.pie(news_df, names='Authenticity',
             title='News Authenticator',
             hover_data=['Authenticity'])
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
news_df.to_csv('news_authenticator.csv')
